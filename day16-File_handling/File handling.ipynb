# %%
new_file = open('file.txt','r')  #opens existing file for reading
if new_file:
    print("File opened")
# Out:
# File opened

# %%
new_file2 = open(r"C:\Users\dasar\OneDrive\Dokumen\Home work\other_file.txt",'r')  #opens existing file for reading
if new_file:
    print("File opened")
# Out:
# File opened

# %%
new_file = open('file.txt','r')  #opens existing file for reading
if new_file:
    print("File opened")
# Out:
# File opened

# %%
with open('file.txt','w') as file:
    file.write("Hello world")

# %%
# Overwrites new contwent wiht old contnet -----> be careful
with open('file.txt','w') as file:
    file.write("Pyhton is very easy")

# %%
file.close()

# %%
with open('file.txt','r') as f:
    content = f.read()    #read entire file content
    print(content)
# Out:
# Pyhton is very easy

# %%
file.close()

# %%
with open(r"C:\Users\dasar\OneDrive\Dokumen\Home work\other_file.txt",'w') as other:
    other.write("Python is simple langauge")

# %%
other.close()

# %%
file = open('file.txt','a') # 'a' means , append new text
file.write(" . It is fastest growing langauge")
file.close()

# %%
with open('file.txt','r') as f:
    content = f.read()    #read entire file content
    print(content)
# Out:
# Pyhton is very easy . It is fastest growing langauge

# %%
f.close()

# %%
with open('file.txt','r') as f:
    content = f.read(11)    #read entire file content
    print(content)
# Out:
# Pyhton is v

# %%
file = open('file.txt','a') # 'a' means , append new text
file.write("\nDeveloped by gudio van rossum\nIt is interpreted langaguge")
file.close()

# %%
with open('file.txt','r') as f:
    content = f.read()    #read entire file content
    print(content)
# Out:
# Pyhton is very easy . It is fastest growing langauge
# Developed by gudio van rossum
# It is interpreted langaguge

# %%
file = open('file.txt','r')
content1 = file.readline()
print(content1)
content2 = file.readline()
print(content2)
content3 = file.readline()
print(content3)
# Out:
# Pyhton is very easy . It is fastest growing langauge
#
# Developed by gudio van rossum
#
# It is interpreted langaguge

# %%
file = open('file.txt','r')
content = file.readlines()
print(content)
# Out:
# ['Pyhton is very easy . It is fastest growing langauge\n', 'Developed by gudio van rossum\n', 'It is interpreted langaguge']

# %%
#read()----read the content
#read(n) ---> read the n charectes
#readline() ---> reads all lines into a list
# readlines() ----> reads all the lines into a list

# %%
# create a new file
file = open("Python_new_file.txt",'x')
file.write("python is very easy\nIt supports many applications")
file.close()

# %%
with open("Python_new_file.txt",'r') as f:
    content = f.read()    #read entire file content
    print(content)
# Out:
# python is very easy
# It supports many applications

# %%
with open('sample.jpg','rb') as file:
    data  = file.read()
    print(f"File size: {len(data)} bytes")
# Out:
# File size: 14380 bytes
